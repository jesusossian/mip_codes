# %% [markdown]
# # ler/resolve .mps ou .lp

# %%
# importando bibliotecas
import gurobipy as gp
from gurobipy import GRB

# %%
# Criando o modelo de um arquivo(mps or lp)
# mudar o caminho do arquivo
model = gp.read("../mps/afiro.mps")

# %%
# resolvendo o modelo
model.optimize()

# %%
# imprimindo o valor ótimo
model.Objval

# %%
# imprimindo a solução diferente de zero
model.printAttr('x')
